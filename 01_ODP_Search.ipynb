# %% [markdown]
# ## Demostration of Interactive Satellite Image Seraching (with AWS Open Data)

# %% [markdown]
# ## Setup

# %%
# Import the os module
import os

path = 'tmp/'

try:
    os.chdir(path)
    print("Current working directory: {0}".format(os.getcwd()))
except FileNotFoundError:
    print("Directory: {0} does not exist".format(path))
except NotADirectoryError:
    print("{0} is not a directory".format(path))
except PermissionError:
    print("You do not have permissions to change to {0}".format(path))
# Out:
# Current working directory: /home/ec2-user/SageMaker/ODP_Demo-main/tmp

# %% [markdown]
# ## Import Libaray

# %%
import leafmap

# %%
url = 'https://earth-search.aws.element84.com/v1/'
collection = 'sentinel-2-l2a'
time_range = "2020-12-01/2020-12-31"
bbox = [-122.2751, 47.5469, -121.9613, 47.7458]

# %% [markdown]
# ## STAC Search & Dataset Query (6 demos)

# %%
search = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    query={"eo:cloud_cover": {"lt": 10}},
    sortby=[{'field': 'properties.eo:cloud_cover', 'direction': 'asc'}],
)
search

# %%
search = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    get_collection=True,
)
# search

# %%
search = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    get_gdf=True,
)
search.head()
# Out:
#                                             geometry  \
# 0  POLYGON ((-123.00025 47.85369, -121.53274 47.8...
# 1  POLYGON ((-123.00025 47.85369, -123.00025 46.8...
# 2  POLYGON ((-122.78713 47.8535, -123.00025 47.27...
# 3  POLYGON ((-122.79462 47.85351, -121.53274 47.8...
# 4  POLYGON ((-123.00025 47.85369, -123.00025 46.8...
#
#                     created     platform constellation instruments  \
# 0  2022-11-06T15:26:41.911Z  sentinel-2b    sentinel-2       [msi]
# 1  2023-08-18T22:50:02.992Z  sentinel-2b    sentinel-2       [msi]
# 2  2023-08-20T03:19:26.086Z  sentinel-2b    sentinel-2       [msi]
# 3  2022-11-06T15:29:35.737Z  sentinel-2b    sentinel-2       [msi]
# 4  2023-07-18T07:29:04.662Z  sentinel-2a    sentinel-2       [msi]
#
#    eo:cloud_cover  mgrs:utm_zone mgrs:latitude_band mgrs:grid_square  \
# 0       64.642105             10                  T               ET
# 1       83.644599             10                  T               ET
# 2       21.615067             10                  T               ET
# 3       22.943574             10                  T               ET
# 4       98.842812             10                  T               ET
#
#     grid:code  ...                                      s2:granule_id  \
# 0  MGRS-10TET  ...  S2B_OPER_MSI_L2A_TL_EPAE_20201231T212743_A0199...
# 1  MGRS-10TET  ...  S2B_OPER_MSI_L2A_TL_S2RP_20230304T134741_A0199...
# 2  MGRS-10TET  ...  S2B_OPER_MSI_L2A_TL_S2RP_20230304T070956_A0199...
# 3  MGRS-10TET  ...  S2B_OPER_MSI_L2A_TL_EPAE_20201228T211944_A0199...
# 4  MGRS-10TET  ...  S2A_OPER_MSI_L2A_TL_S2RP_20230305T133645_A0287...
#
#    s2:reflectance_conversion_factor                     datetime  s2:sequence  \
# 0                          1.034125  2020-12-31T19:21:21.475000Z            0
# 1                          1.034125  2020-12-31T19:21:21.474000Z            1
# 2                          1.033888  2020-12-28T19:11:24.522000Z            1
# 3                          1.033888  2020-12-28T19:11:24.522000Z            0
# 4                          1.033680  2020-12-26T19:21:22.739000Z            1
#
#                                  earthsearch:s3_path  \
# 0  s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/T/E...
# 1  s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/T/E...
# 2  s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/T/E...
# 3  s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/T/E...
# 4  s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/T/E...
#
#                               earthsearch:payload_id  \
# 0  roda-sentinel2/workflow-sentinel2-to-stac/6658...
# 1  roda-sentinel2/workflow-sentinel2-to-stac/81d2...
# 2  roda-sentinel2/workflow-sentinel2-to-stac/818b...
# 3  roda-sentinel2/workflow-sentinel2-to-stac/e6b4...
# 4  roda-sentinel2/workflow-sentinel2-to-stac/8387...
#
#    earthsearch:boa_offset_applied             processing:software  \
# 0                           False  {'sentinel2-to-stac': '0.1.0'}
# 1                            True  {'sentinel2-to-stac': '0.1.1'}
# 2                            True  {'sentinel2-to-stac': '0.1.1'}
# 3                           False  {'sentinel2-to-stac': '0.1.0'}
# 4                            True  {'sentinel2-to-stac': '0.1.1'}
#
#                     updated   proj:code
# 0  2022-11-06T15:26:41.911Z  EPSG:32610
# 1  2023-08-18T22:50:02.992Z  EPSG:32610
# 2  2023-08-20T03:19:26.086Z  EPSG:32610
# 3  2022-11-06T15:29:35.737Z  EPSG:32610
# 4  2023-07-18T07:29:04.662Z  EPSG:32610
#
# [5 rows x 42 columns]

# %%
search = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    get_assets=True,
)
# search

# %%
search = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    get_info=True,
)
# search

# %%
search = leafmap.stac_search(
    url=url,
    max_items=10,
    collections=[collection],
    bbox=bbox,
    datetime=time_range,
    get_links=True,
)
search
# Out:
# ['https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_10TET_20201231_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_10TET_20201231_1_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_10TET_20201228_1_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_10TET_20201228_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TET_20201226_1_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TET_20201226_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TET_20201223_1_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2A_10TET_20201223_0_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_10TET_20201221_1_L2A',
#  'https://earth-search.aws.element84.com/v1/collections/sentinel-2-l2a/items/S2B_10TET_20201221_0_L2A']

# %% [markdown]
# ## Visualize Open Geospatial Dataset Interactively

# %% [markdown]
# Setup interactive map configuration

# %%
m = leafmap.Map(
    center=[37.7517, -122.4433], zoom=8,
    attribution_control=False,
)
m
# Out:
# Map(center=[37.7517, -122.4433], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %% [markdown]
# ## Search Results Access (Pull from S3)

# %%
# m.stac_gdf  # The GeoDataFrame of the STAC search results

# %%
# m.stac_dict  # The STAC search results as a dictionary

# %%
# m.stac_item  # The selected STAC item of the search result
